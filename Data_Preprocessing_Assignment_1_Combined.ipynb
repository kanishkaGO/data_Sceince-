# %% [markdown]
# # Data Preprocessing Assignment 1
#
# Combined notebook containing Questions 1–4.

# %% [markdown]
# ## Note
#
# This compact GitHub version contains the assignment notebook structure and analysis cells with outputs removed for repository size/readability.
